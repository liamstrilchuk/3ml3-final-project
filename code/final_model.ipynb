# %%
from model import Model

model = Model()
model.create(drop_data=0, dropout=0.3, max_features=5000, layer_size_factor=0.25)
model.train(epochs=20)
# Out:
# Epoch 1/20
# 1147/1147 [==============================] - 11s 9ms/step - loss: 0.1601 - accuracy: 0.5152 - val_loss: 0.0741 - val_accuracy: 0.7190
# Epoch 2/20
# 1147/1147 [==============================] - 11s 9ms/step - loss: 0.0777 - accuracy: 0.6881 - val_loss: 0.0591 - val_accuracy: 0.7092
# Epoch 3/20
# 1147/1147 [==============================] - 10s 9ms/step - loss: 0.0633 - accuracy: 0.7103 - val_loss: 0.0562 - val_accuracy: 0.7109
# Epoch 4/20
# 1147/1147 [==============================] - 10s 9ms/step - loss: 0.0559 - accuracy: 0.7216 - val_loss: 0.0548 - val_accuracy: 0.7094
# Epoch 5/20
# 1147/1147 [==============================] - 10s 8ms/step - loss: 0.0500 - accuracy: 0.7323 - val_loss: 0.0546 - val_accuracy: 0.7165
# Epoch 6/20
# 1147/1147 [==============================] - 12s 10ms/step - loss: 0.0457 - accuracy: 0.7378 - val_loss: 0.0552 - val_accuracy: 0.7205
# Epoch 7/20
# 1147/1147 [==============================] - 12s 10ms/step - loss: 0.0416 - accuracy: 0.7427 - val_loss: 0.0571 - val_accuracy: 0.7178
# (<keras.src.callbacks.History at 0x76765ea2f760>, 75.06855201721191)

# %%
def print_sorted_report(model):
	report_dict = model.get_report(output_dict=True, threshold=0.7)
	report_dict = sorted(report_dict.items(), key=lambda i: i[1]["f1-score"], reverse=True)

	for proj, scores in report_dict:
		print(f"{proj:<30} {round(scores['precision'], 3):<5} {round(scores['recall'], 3):<5} {round(scores['f1-score'], 3):<5}")

print_sorted_report(model)
# Out:
# 319/319 [==============================] - 1s 2ms/step
# WikiProject Football           0.989 0.911 0.949
# WikiProject Biography          0.97  0.924 0.946
# WikiProject Albums             0.988 0.89  0.936
# WikiProject Songs              0.989 0.887 0.935
# WikiProject Plants             0.962 0.905 0.933
# WikiProject Trains             0.982 0.883 0.93
# WikiProject Australia          0.99  0.836 0.906
# WikiProject Film               0.978 0.842 0.904
# WikiProject Aviation           0.968 0.826 0.891
# WikiProject Iran               0.957 0.826 0.887
# WikiProject Poland             0.992 0.797 0.884
# WikiProject Japan              0.956 0.762 0.848
# micro avg                      0.953 0.75  0.84
# WikiProject Cities             0.914 0.763 0.832
# WikiProject Television         0.934 0.746 0.83
# weighted avg                   0.946 0.75  0.828
# WikiProject India              0.961 0.727 0.828
# macro avg                      0.947 0.733 0.819
# WikiProject Canada             0.929 0.727 0.815
# samples avg                    0.882 0.776 0.807
# WikiProject Military history   0.93  0.712 0.807
# WikiProject Germany            0.925 0.701 0.798
# WikiProject Russia             0.949 0.677 0.79
# WikiProject Olympics           0.953 0.673 0.789
# WikiProject Africa             0.944 0.542 0.689
# WikiProject France             0.916 0.545 0.684
# WikiProject Christianity       0.883 0.525 0.659
# WikiProject Geography          0.889 0.355 0.508
# WikiProject United States      0.824 0.354 0.495

# %%
model.optimize_thresholds(step=0.01)
print_sorted_report(model)
# Out:
# 319/319 [==============================] - 1s 2ms/step
# WikiProject Football           0.989 0.918 0.952
# WikiProject Albums             0.988 0.899 0.941
# WikiProject Biography          0.979 0.9   0.938
# WikiProject Songs              0.991 0.883 0.934
# WikiProject Plants             0.976 0.877 0.924
# WikiProject Trains             0.989 0.864 0.922
# WikiProject Australia          0.991 0.844 0.911
# WikiProject Film               0.978 0.843 0.905
# WikiProject Japan              0.95  0.849 0.897
# WikiProject Poland             0.992 0.808 0.891
# WikiProject Iran               0.967 0.813 0.884
# WikiProject Aviation           0.978 0.795 0.877
# WikiProject India              0.959 0.768 0.853
# micro avg                      0.959 0.749 0.841
# WikiProject Canada             0.932 0.762 0.838
# weighted avg                   0.952 0.749 0.832
# macro avg                      0.951 0.739 0.826
# WikiProject Russia             0.944 0.726 0.821
# WikiProject Television         0.948 0.716 0.816
# samples avg                    0.883 0.775 0.807
# WikiProject Germany            0.939 0.684 0.792
# WikiProject Olympics           0.955 0.673 0.79
# WikiProject Military history   0.952 0.666 0.784
# WikiProject Cities             0.967 0.626 0.76
# WikiProject Christianity       0.873 0.614 0.721
# WikiProject France             0.914 0.581 0.711
# WikiProject Africa             0.945 0.546 0.692
# WikiProject Geography          0.853 0.429 0.571
# WikiProject United States      0.826 0.378 0.519

# %%
model.optimized_thresholds
# Out:
# array([0.69, 0.68, 0.67, 0.8 , 0.81, 0.62, 0.56, 0.86, 0.68, 0.67, 0.63,
#        0.63, 0.74, 0.61, 0.76, 0.47, 0.8 , 0.71, 0.85, 0.62, 0.58, 0.74,
#        0.78, 0.85, 0.68])

# %%
model.wrong_where(project="WikiProject Africa")
# Out:
# [{'text': 'Peros Banhos, Pedro dos Banhos or Baixos de Pêro dos Banhos in old maps, is an inhabited atoll in the Chagos Archipelago. It had been uninhabited from the expulsion of the Chagossians in 1971 until a group of four Chagossians returned to establish a settlement in 2026 on the Île du Coin. Île Yeye, located at the northeastern corner of the atoll, is the island of the Chagos Archipelago that is closest to the Maldives.',
#   'actual': ('WikiProject Africa', 'WikiProject Geography'),
#   'predicted': ('WikiProject Africa', 'WikiProject Biography')},
#  {'text': 'The 2021 World Athletics U20 Championships, also known as the World Junior Championships, was an international athletics competition for athletes qualifying as juniors (born no earlier than 1 January 2002), which was held from 18 to 22 August 2021 at the Moi International Sports Centre in Nairobi, Kenya.',
#   'actual': ('WikiProject Africa',),
#   'predicted': ('WikiProject Africa', 'WikiProject Biography')},
#  {'text': 'In 2021, Niger was affected by recurring floods caused by heavy rains, resulting in several deaths and widespread damage nationwide, with Niamey being the most affected area. As of August 23, 2021, at least 62 people died, 60 injured, and 105,690 individuals affected by the floods. Most of the fatalities were reported in the Maradi Region, with 18 deaths.',
#   'actual': ('WikiProject Africa',),
#   'predicted': ('WikiProject Africa', 'WikiProject Biography')},
#  {'text': 'The Diocese of Kumba (Latin: Diocesis Kumbana; French: Diocèse de Kumba) is a diocese of the Roman Catholic Church in the African country of Cameroon. Headquartered in Kumba, the diocesan cathedral is the Cathedral of the Sacred Heart and its bishop is Agapitus Enuyehnyoh Nfon. The diocese was created on 15 March 2016 by Pope Francis from territory in the Diocese of Buéa, and it is a suffragan diocese of the Archdiocese of Bamenda.',
#   'actual': ('WikiProject Africa',),
#   'predicted': ('WikiProject Africa', 'WikiProject Biography')},
#  {'text': "The Tondeka Metropolitan Kampala Bus Service (TMBS) is the proposed principal public transport operator in the Kampala metropolitan area. Expected to start in September 2020, the bus system, Tondeka Metro, proposes to serve the city of Kampala, Uganda's capital, the city of Entebbe, including Entebbe International Airport, Buloba, Nsangi, Ssabagabo, Mukono, Kira Town, Matugga, Wakiso, and the areas in Mukono District and Wakiso District that connect with these urban centers.",
#   'actual': ('WikiProject Africa',),
#   'predicted': ('WikiProject Africa', 'WikiProject Biography')}]

# %%
model.save("final")
